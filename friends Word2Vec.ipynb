# %%
import numpy as np
import pandas as pd

# %%
import gensim

# %%
import os

# %%
path = "D:\\EXCELR\\archive"

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\EXCELR\\Untitled Folder'

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'D:\\EXCELR\\archive'

# %%
os.listdir()
# Out:
# ['S01E01 Monica Gets A Roommate.txt',
#  'S01E02 The Sonogram At The End.txt',
#  'S01E03 The Thumb.txt',
#  'S01E04 George Stephanopoulos.txt',
#  'S01E05 The East German Laundry Detergent.txt',
#  'S01E06 The Butt.txt',
#  'S01E07 The Blackout.txt',
#  'S01E08 Nana Dies Twice.txt',
#  'S01E09 Underdog Gets Away.txt',
#  'S01E10 The Monkey.txt',
#  'S01E11 Mrs. Bing.txt',
#  'S01E12 The Dozen Lasagnas.txt',
#  'S01E13 The Boobies.txt',
#  'S01E14 The Candy Hearts.txt',
#  'S01E15 The Stoned Guy.txt',
#  'S01E16 The Two Parts Part I.txt',
#  'S01E17 The Two Parts Part II.txt',
#  'S01E18 All The Poker.txt',
#  'S01E19 The Monkey Gets Away.txt',
#  'S01E20 The Evil Orthodontist.txt',
#  'S01E21 The Fake Monica.txt',
#  'S01E22 The Ick Factor.txt',
#  'S01E23 The Birth.txt',
#  'S01E24 Rachel Finds Out.txt',
#  'S02E01 Rosss New Girlfriend.txt',
#  'S02E02 The Breast Milk.txt',
#  'S02E03 Heckles Dies.txt',
#  'S02E04 Phoebes Husband.txt',
#  'S02E05 Five Steaks And An Eggplant.txt',
# ...

# %%
os.path.join(path,os.listdir()[0])
# Out:
# 'D:\\EXCELR\\archive\\S01E01 Monica Gets A Roommate.txt'

# %%
open(os.path.join(path,os.listdir()[0])).read()
# Out:
# 'The One Where Monica Gets a New Roommate (The Pilot-The Uncut Version)\nWritten by: Marta Kauffman & David Crane\n\n\n[Scene: Central Perk, Chandler, Joey, Phoebe, and Monica are there.]\n\nMonica: There\'s nothing to tell! He\'s just some guy I work with!\n\nJoey: C\'mon, you\'re going out with the guy! There\'s gotta be something wrong with him!\n\nChandler: All right Joey, be nice.  So does he have a hump? A hump and a hairpiece?\n\nPhoebe: Wait, does he eat chalk?\n\n(They all stare, bemused.)\n\nPhoebe: Just, \'cause, I don\'t want her to go through what I went through with Carl- oh!\n\nMonica: Okay, everybody relax. This is not even a date. It\'s just two people going out to dinner and- not having sex.\n\nChandler: Sounds like a date to me.\n\n[Time Lapse]\n\nChandler: Alright, so I\'m back in high school, I\'m standing in the middle of the cafeteria, and I realize I am totally naked.\n\nAll: Oh, yeah. Had that dream.\n\nChandler: Then I look down, and I realize there\'s a pho
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir():
    
    corpus = open(os.path.join(path,filename),encoding='utf-8').read()
    #corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['the',
#   'one',
#   'where',
#   'monica',
#   'gets',
#   'new',
#   'roommate',
#   'the',
#   'pilot',
#   'the',
#   'uncut',
#   'version',
#   'written',
#   'by',
#   'marta',
#   'kauffman',
#   'david',
#   'crane',
#   'scene',
#   'central',
#   'perk',
#   'chandler',
#   'joey',
#   'phoebe',
#   'and',
#   'monica',
#   'are',
#   'there'],
#  ['monica', 'there', 'nothing', 'to', 'tell'],
#  ['he', 'just', 'some', 'guy', 'work', 'with'],
#  ['joey', 'mon', 'you', 're', 'going', 'out', 'with', 'the', 'guy'],
#  ['there', 'gotta', 'be', 'something', 'wrong', 'with', 'him'],
#  ['chandler', 'all', 'right', 'joey', 'be', 'nice'],
#  ['so', 'does', 'he', 'have', 'hump'],
#  ['hump', 'and', 'hairpiece'],
#  ['phoebe', 'wait', 'does', 'he', 'eat', 'chalk'],
#  ['they', 'all', 'stare', 'bemused'],
#  ['phoebe',
#   'just',
#   'cause',
#   'don',
#   'want',
#   'her',
#   'to',
#   'go',
#   'through',
#   'what',
#   'went',
#   'through',
#   'with',
#   'carl',
# ...

# %%
len(story)
# Out:
# 115858

# %%
model = gensim.models.Word2Vec(window=10, min_count=2)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (2951922, 4215490)

# %%
model.wv.most_similar('friends')
# Out:
# [('life', 0.7628507018089294),
#  ('parents', 0.758131742477417),
#  ('kids', 0.7451694011688232),
#  ('best', 0.724726140499115),
#  ('having', 0.7237022519111633),
#  ('family', 0.7177097201347351),
#  ('father', 0.7175960540771484),
#  ('children', 0.7161495685577393),
#  ('friend', 0.7011487483978271),
#  ('songs', 0.6910254955291748)]

# %%
model.wv.most_similar('joey')
# Out:
# [('ross', 0.8617588877677917),
#  ('chandler', 0.7754663228988647),
#  ('monica', 0.7562202215194702),
#  ('phoebe', 0.7534974813461304),
#  ('mike', 0.6435727477073669),
#  ('rachel', 0.6431369781494141),
#  ('janine', 0.6177581548690796),
#  ('mailbox', 0.6099988222122192),
#  ('laptop', 0.5981513857841492),
#  ('kathy', 0.5965595245361328)]

# %%
model.wv.most_similar("ross")
# Out:
# [('joey', 0.8617589473724365),
#  ('phoebe', 0.8615831136703491),
#  ('chandler', 0.8147596716880798),
#  ('monica', 0.8007945418357849),
#  ('rachel', 0.7679989337921143),
#  ('mike', 0.7022652626037598),
#  ('richard', 0.6552439332008362),
#  ('emily', 0.6200446486473083),
#  ('charlie', 0.6122028827667236),
#  ('janice', 0.5990221500396729)]

# %%
model.wv.most_similar("marriage")
# Out:
# [('special', 0.8261164426803589),
#  ('effectively', 0.8122866153717041),
#  ('decision', 0.811570942401886),
#  ('real', 0.810472846031189),
#  ('friendship', 0.8062142133712769),
#  ('stupid', 0.7946856021881104),
#  ('commitment', 0.7941146492958069),
#  ('horrible', 0.792405903339386),
#  ('divorce', 0.7904677391052246),
#  ('speech', 0.790121853351593)]

# %%
model.wv.most_similar("date")
# Out:
# [('list', 0.6566265225410461),
#  ('vacation', 0.6276566982269287),
#  ('honeymoon', 0.6199774742126465),
#  ('crush', 0.6163531541824341),
#  ('purpose', 0.6084100008010864),
#  ('spend', 0.6035032868385315),
#  ('sex', 0.5957597494125366),
#  ('trip', 0.5881457328796387),
#  ('cheating', 0.5880343914031982),
#  ('relationship', 0.5776498317718506)]

# %%
model.wv.most_similar("wine")
# Out:
# [('bottle', 0.904556155204773),
#  ('glass', 0.8915820717811584),
#  ('tray', 0.8887091279029846),
#  ('cup', 0.8853928446769714),
#  ('bucket', 0.8826907277107239),
#  ('bags', 0.8695222735404968),
#  ('refrigerator', 0.8692794442176819),
#  ('pours', 0.8690807819366455),
#  ('stack', 0.8689553141593933),
#  ('pile', 0.8682952523231506)]

# %%
model.wv.most_similar("geller")
# Out:
# [('zelner', 0.8765366077423096),
#  ('treeger', 0.853962779045105),
#  ('bing', 0.84406977891922),
#  ('potter', 0.8384414911270142),
#  ('greene', 0.8367286920547485),
#  ('waltham', 0.8366218209266663),
#  ('green', 0.8235901594161987),
#  ('girabaldi', 0.8203166723251343),
#  ('bowmont', 0.8152086734771729),
#  ('heckles', 0.8101930618286133)]

# %%
model.wv.doesnt_match(['joey','ross','monica','chandler','rachel','carol'])
# Out:
# 'carol'

# %%
model.wv.doesnt_match(['rachel', 'monica', 'phoebe', 'ross'])
# Out:
# 'rachel'

# %%
model.wv.doesnt_match(['rachel', 'monica', 'phoebe', 'ross','susan'])
# Out:
# 'susan'

# %%
model.wv.most_similar("sex")
# Out:
# [('ever', 0.7082386612892151),
#  ('today', 0.675682783126831),
#  ('relationship', 0.6726440787315369),
#  ('feelings', 0.6711227297782898),
#  ('never', 0.6708089709281921),
#  ('even', 0.6514667272567749),
#  ('always', 0.6442071199417114),
#  ('because', 0.6427218317985535),
#  ('married', 0.6424240469932556),
#  ('kids', 0.6383597254753113)]

# %%
model.wv.similarity('rachel','ross')
# Out:
# 0.767999

# %%
model.wv.similarity('rachel','chandler')
# Out:
# 0.8431918

# %%
model.wv.similarity('monica','chandler')
# Out:
# 0.75918305

# %%
model.wv['joey']
# Out:
# array([-0.16217867,  0.30360568,  1.5871012 ,  1.7728124 ,  0.23199624,
#         0.07115965, -0.7487248 ,  0.78031224,  0.23543069, -0.8734901 ,
#        -0.868754  , -0.24439031, -0.9120362 , -0.01419431,  0.7728039 ,
#        -0.1842546 , -0.05383726,  0.07691848, -0.09965367, -1.0492444 ,
#        -0.6664428 , -0.18010159,  0.3476882 ,  0.6308235 , -0.81645036,
#         0.15852599,  0.5135064 ,  0.30754519, -0.58741724,  0.00264712,
#         0.77346516,  0.418959  , -0.4704878 ,  0.41173777, -0.01043564,
#        -0.5965737 ,  0.8522332 , -0.16637686, -0.6525373 , -0.49954855,
#        -0.09521544,  0.5730701 , -0.3843036 , -1.1773642 ,  0.55875075,
#        -0.99793947, -0.6587988 ,  0.1879891 ,  0.09575238,  0.87883675,
#         0.04463208, -0.14299083, -0.8208089 ,  0.23250896,  0.11376322,
#        -0.33831283, -0.10788368,  0.23895288,  0.36269945, -0.4199805 ,
#        -0.07406346,  0.28177983,  0.15446337,  0.01220469, -0.5311657 ,
# ...

# %%
model.wv.get_normed_vectors()
# Out:
# array([[ 0.02909336,  0.09110522,  0.125277  , ...,  0.02807485,
#          0.06177462, -0.01940375],
#        [-0.1215914 ,  0.08310465,  0.20702977, ..., -0.09536582,
#         -0.05731287, -0.02936726],
#        [-0.23266256, -0.01367109, -0.00638949, ..., -0.06495341,
#          0.11198342, -0.09303924],
#        ...,
#        [-0.26437452,  0.05663926,  0.16526994, ...,  0.0817557 ,
#          0.01192331, -0.01657455],
#        [-0.01703664,  0.24303028,  0.03356097, ..., -0.1069983 ,
#         -0.0779051 , -0.05947603],
#        [-0.11992519,  0.11565053,  0.07669912, ..., -0.11016791,
#         -0.00316961, -0.07019369]], dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['you',
#  'the',
#  'to',
#  'and',
#  'it',
#  'ross',
#  'rachel',
#  'joey',
#  'chandler',
#  'monica',
#  'that',
#  'phoebe',
#  'is',
#  'what',
#  'oh',
#  'in',
#  'know',
#  'of',
#  'no',
#  'we',
#  'this',
#  'on',
#  'just',
#  'he',
#  'me',
#  'so',
#  'my',
#  'with',
#  'she',
#  'her',
#  'yeah',
#  'are',
#  'okay',
#  're',
#  'do',
#  'for',
#  'have',
#  'not',
#  'all',
#  'don',
#  'well',
#  'can',
#  'hey',
#  'was',
#  'up',
#  'but',
#  'at',
#  'be',
#  'out',
#  'they',
#  'right',
#  'there',
#  'like',
#  'your',
#  'scene',
#  'get',
#  'him',
#  'about',
#  'his',
#  'gonna',
#  'go',
#  'one',
#  'here',
#  'uh',
#  'really',
#  'look',
#  'if',
#  'think',
#  'how',
#  'll',
#  'now',
#  'see',
#  'from',
#  'mean',
#  'back',
#  'did',
#  'got',
#  'as',
#  'good',
#  'why',
#  'come',
#  'want',
#  'then',
#  'god',
#  'who',
#  've',
#  'would',
#  'when',
#  'guys',
#  'going',
#  'over',
#  'sorry',
#  'time',
#  'hi',
#  'down',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (10550, 3)

# %%
import plotly.express as px
fig = px.scatter_3d(X[:100],x=0,y=1,z=2, color=y[:100])
fig.show()
# Out:
# <div>                            <div id="de3e3f7b-3c72-4cc9-befc-9ddd04d0694b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de3e3f7b-3c72-4cc9-befc-9ddd04d0694b")) {                    Plotly.newPlot(                        "de3e3f7b-3c72-4cc9-befc-9ddd04d0694b",                        [{"hovertemplate":"color=you<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"you","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"you","scene":"scene","showlegend":true,"x":[0.723026692867279],"y":[0.6061634421348572],"z":[0.02655702270567417],"type":"scatter3d"},{"hovertemplate":"color=the<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"the","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"t
# ...
